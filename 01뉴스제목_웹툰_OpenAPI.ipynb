# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확인
# !pip show requests

# %%
# beautifulsoup4 라이브러리 설치여부 확인
# !pip show beautifulsoup4

# %%
# reqeusts, bs4 import
import requests
import bs4
# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print(f'requests 버전 = {requests.__version__}')
print(f'bs4 버전 = {bs4.__version__}')

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스 
#url = 'https://news.naver.com/section/105'

# dict타입으로 요청 파라미터 설정
req_param = {
    'sid': 105
}
# 
url = 'https://news.naver.com/section/{sid}'.format(**req_param) # **은 파라미터 전달할 때
print(url)

# 요청 헤더 설정 : 브라우저 정보 (사람처럼 보이게 하기 위함)
req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/142.0.0.0 Whale/4.35.351.16 Safari/537.36'
}

# requests 의 get() 함수 호출하기 
res = requests.get(url, headers=req_header)
print(res.status_code)
print(res.ok)
print(type(res))
##print(res.text)  #페이지소스보기해서 나오는 텍스트들 가져오는 것
# 응답(response)이 OK 이면
# 응답 (response)에서 text 추출
# BeautifulSoup 객체 생성  
if res.ok:  #조건문 쓰고 아무것도 쓰지 않으면 오류남. pass 쓰면 오류 안남
    soup = BeautifulSoup(res.text,'html.parser') 
    print(len(soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/']")))  #a 앞에 있는 클래스 가져와서 범위 좁히기
    # CSS 선택자를 사용해서 a tag 목록 가져오기
    a_tags = soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/']")
    print(type(a_tags), type(a_tags[0])) # [Tag,Tag]
    # <a> 태그 리스트 순회하기
    for a_tag in a_tags:
        title = a_tag.text.strip() #strip()함수 = 공백 좀 줄일때 씀
        link = a_tag['href']
        print(title, link)
else:
    # 응답(response)이 Error 이면 status code 출력  
    print(f'Error code = {res.status_code}')
# Out:
# https://news.naver.com/section/105
# 200
# True
# <class 'requests.models.Response'>
# 88
# <class 'bs4.element.ResultSet'> <class 'bs4.element.Tag'>
# 김성훈 업스테이지 대표 "韓 몰트북, 두려움보다 적극적 참여 필요" https://n.news.naver.com/mnews/article/092/0002409690
#  https://n.news.naver.com/mnews/article/comment/092/0002409690
# "올 하반기 베일 벗는 스페이스X…우주항공 ‘몸값' 재평가" https://n.news.naver.com/mnews/article/018/0006215282
#  https://n.news.naver.com/mnews/article/comment/018/0006215282
# 국가AI전략위, 소버린 AI 등 '한-UAE AI·디지털 협력' 구체화 https://n.news.naver.com/mnews/article/030/0003397420
#  https://n.news.naver.com/mnews/article/comment/030/0003397420
# “AI가 사람 대신 PC 조작” 영화 ‘아이언맨’ 자비스 현실 됐다…네이버 등 ‘사용 금지령’ https://n.news.naver.com/mnews/article/029/0003009730
#  https://n.news.naver.com/mnews/article/comment/029/0003009730
# 아이템베이, '리니지 클래식' 출시 맞아 20억원 규모 프로모션... 유저 당 10만 마일리지 지급 https://n.news.naver.com/mnews/article/030/0003397368
#  https://n.news.naver.com/mnews/article/comment/030/0003397368
# 주가 출렁이는 구글·아마존·메타 …"AI곳간은 문제없다" https://n.news.naver.com/mnews/article/009/0005634112
#  https://n.news.naver.com/mnews/article/comment/009/0005634112
# 카이스트, 차세대 메모리 열쇠 ‘텔루륨’ 스위칭 원리 밝혔다 https://n.news.naver.com/mnews/article/021/0002769708
#  https://n.news.naver.com/mnews/article/comment/021/0002769708
# 원자 하나로 수소·산소 동시에 만든다[과학을읽다] https://n.news.naver.com/mnews/article/277/0005718564
#  https://n.news.naver.com/mnews/article/comment/277/0005718564
# 사진 한장으로 1분만에 가상세계 구현… 게임업계  [조윤주의 테크 시그널] https://n.news.naver.com/mnews/article/014/0005475089
#  https://n.news.naver.com/mnews/article/comment/014/0005475089
# "어떤 데이터 유출될지 몰라"…네이버·카카오, 오픈클로 사용 금지령 https://n.news.naver.com/mnews/article/008/0005315639
#  https://n.news.naver.com/mnews/article/comment/008/0005315639
# 삼성 HBM4 설 직후 출하... 내달 엔비디아 최신 AI 가속기 탑재 공개 유력 https://n.news.naver.com/mnews/article/469/0000913458
#  https://n.news.naver.com/mnews/article/comment/469/0000913458
# 카이스트 26일 새 총장 표결... 선출 불발되면 이사회 책임론 커질 듯 https://n.news.naver.com/mnews/article/469/0000913457
#  https://n.news.naver.com/mnews/article/comment/469/0000913457
# 韓 학자 참여 AI, 세계적 수학 난제 13개 풀었다 https://n.news.naver.com/mnews/article/011/0004588010
#  https://n.news.naver.com/mnews/article/comment/011/0004588010
# “아이언맨 도우미 자비스가 울트론될라” 네카당, ‘PC 조작’ AI ‘오픈클로’ 사용금지령 https://n.news.naver.com/mnews/article/029/0003009739
#  https://n.news.naver.com/mnews/article/comment/029/0003009739
# 삼성전자, 美 특허 취득 수 4년 연속 1위…삼성디플은 5위 https://n.news.naver.com/mnews/article/366/0001141270
#  https://n.news.naver.com/mnews/article/comment/366/0001141270
# 제약사 대세 투자처는 어디?… 반려동물·디지털헬스케어에 시선 https://n.news.naver.com/mnews/article/029/0003009738
#  https://n.news.naver.com/mnews/article/comment/029/0003009738
# 가발 수출국에서 '양자·AI 강국'으로 … K과학기술, 기적의 60년 https://n.news.naver.com/mnews/article/009/0005634160
#  https://n.news.naver.com/mnews/article/comment/009/0005634160
# ‘인간 개입 없는 AI SNS’ 몰트북, 보안 위협도 함께 부상 https://n.news.naver.com/mnews/article/009/0005634151
#  https://n.news.naver.com/mnews/article/comment/009/0005634151
# 돈 아닌 ‘독’ 될라…‘AI 쓰레기’ 단속 나선 플랫폼들 [팩플] https://n.news.naver.com/mnews/article/025/0003501832
#  https://n.news.naver.com/mnews/article/comment/025/0003501832
# 투자·인력 블랙홀 된 AI … 빅테크, 올 7000억불 투입 https://n.news.naver.com/mnews/article/009/0005634134
#  https://n.news.naver.com/mnews/article/comment/009/0005634134
# 위성신호 끊기면 대재앙…'GPS 독립' 필요하죠 https://n.news.naver.com/mnews/article/009/0005634116
#  https://n.news.naver.com/mnews/article/comment/009/0005634116
# 美 빅테크 4사, 韓정부 예산보다 많은 982조 AI 투자 https://n.news.naver.com/mnews/article/023/0003957907
#  https://n.news.naver.com/mnews/article/comment/023/0003957907
# 주가 출렁이는 구글·아마존·메타 …"AI곳간은 문제없다" https://n.news.naver.com/mnews/article/009/0005634112
#  https://n.news.naver.com/mnews/article/comment/009/0005634112
# 삼성전자 HBM4, 설 이후 양산 출하…주도권 경쟁 고조 https://n.news.naver.com/mnews/article/032/0003426521
#  https://n.news.naver.com/mnews/article/comment/032/0003426521
# 최수연 네이버 대표, 유명인 지식인 답변 노출에 공식 사과… 개보위 신고 https://n.news.naver.com/mnews/article/366/0001141266
#  https://n.news.naver.com/mnews/article/comment/366/0001141266
# 이랜텍, LG에너지솔루션 ESS 사업에 BMS 공급 https://n.news.naver.com/mnews/article/030/0003397500
#  https://n.news.naver.com/mnews/article/comment/030/0003397500
# 삼성D, 애플 폴더블 OLED 증설 투자 추진 https://n.news.naver.com/mnews/article/030/0003397498
#  https://n.news.naver.com/mnews/article/comment/030/0003397498
# 한·중·대만, 마이크로 LED 활용한 광반도체 생태계 구축 경쟁 https://n.news.naver.com/mnews/article/030/0003397497
#  https://n.news.naver.com/mnews/article/comment/030/0003397497
# AI전용 SNS에 이어 이번엔 ‘AI 고용주’...AI가 사람에 일시키고 일당 지급 https://n.news.naver.com/mnews/article/023/0003957903
#  https://n.news.naver.com/mnews/article/comment/023/0003957903
# '땀내 나는 AI' 팰런티어 비즈니스가 뜬다 https://n.news.naver.com/mnews/article/015/0005248397
#  https://n.news.naver.com/mnews/article/comment/015/0005248397
# 게임 스타트업 투자, 5년래 최저…AI 쏠림에 자금 말랐다 https://n.news.naver.com/mnews/article/018/0006215321
#  https://n.news.naver.com/mnews/article/comment/018/0006215321
# 드림씨아이에스 "임상 자문사 인수로 시너지" https://n.news.naver.com/mnews/article/015/0005248384
#  https://n.news.naver.com/mnews/article/comment/015/0005248384
# 면역질환 치료제 특허 줄줄이 만료…33조 시장 열린다 https://n.news.naver.com/mnews/article/015/0005248383
#  https://n.news.naver.com/mnews/article/comment/015/0005248383
# 스페이스X 모바일 기기 개발설 ‘솔솔’… 글로벌 통신 시장 판도 바뀐다 https://n.news.naver.com/mnews/article/029/0003009722
#  https://n.news.naver.com/mnews/article/comment/029/0003009722
# ‘AI붐’ 타고 글로벌 PC 공급망 뚫는 中 메모리 https://n.news.naver.com/mnews/article/023/0003957899
#  https://n.news.naver.com/mnews/article/comment/023/0003957899
# 카카오 잔혹사⑤ 문어발 기업인가, 데이터 시대의 유기체인가 https://n.news.naver.com/mnews/article/018/0006215313
#  https://n.news.naver.com/mnews/article/comment/018/0006215313
# [이내찬교수의 광고로보는 통신역사] 〈51〉청소년을 유혹하는 국제폰팅 https://n.news.naver.com/mnews/article/030/0003397487
#  https://n.news.naver.com/mnews/article/comment/030/0003397487
# 국가대표AI, 1차 단계평가 결과 보니… LG 독주속 SKT 2위 점프 https://n.news.naver.com/mnews/article/030/0003397471
#  https://n.news.naver.com/mnews/article/comment/030/0003397471
# LG전자, 로봇 ETF 편입 확장 추진…주가 부양 '핵심 키' https://n.news.naver.com/mnews/article/030/0003397470
#  https://n.news.naver.com/mnews/article/comment/030/0003397470
# 엔씨소프트 ‘리니지 클래식’, 과거 모습 그대로 돌아왔다 https://n.news.naver.com/mnews/article/029/0003009709
#  https://n.news.naver.com/mnews/article/comment/029/0003009709
# 비트코인 침체에 ‘오지급’ 리스크까지… 빗썸 IPO 차질 빚나 https://n.news.naver.com/mnews/article/029/0003009708
#  https://n.news.naver.com/mnews/article/comment/029/0003009708
# “20만전자 재시동”…삼성전자, HBM4 최초 양산 임박 https://n.news.naver.com/mnews/article/029/0003009706
#  https://n.news.naver.com/mnews/article/comment/029/0003009706
# KT 이사회, 9일 사외이사 교체 착수…국민연금·노조 압박 속 ‘결자해지’ 시험대 https://n.news.naver.com/mnews/article/018/0006215303
#  https://n.news.naver.com/mnews/article/comment/018/0006215303
# 美 빅테크, 데이터 수집·정제 자동화 승부수…"AI 경쟁력 핵심" https://n.news.naver.com/mnews/article/092/0002409728
#  https://n.news.naver.com/mnews/article/comment/092/0002409728

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

#section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}
section_dict = {'정치':100,'경제':101,'사회':102,'생활/문화':103,'세계':104,'IT/과학':105}
def print_news(section_name):  #print_new(103,'생활/문화') 
    sid = section_dict.get(section_name, '정치')
    url = f'https://news.naver.com/section/{sid}'
    print(f'{section_name} 뉴스 {url}')
    req_header = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/142.0.0.0 Whale/4.35.351.16 Safari/537.36'
    }
    res = requests.get(url, headers=req_header)
    if res.ok:
        soup = BeautifulSoup(res.text,'html.parser') 
        # CSS 선택자를 사용해서 a tag 목록 가져오기
        a_tags = soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/']")
        # <a> 태그 리스트 순회하기
        for a_tag in a_tags:
            title = a_tag.text.strip() 
            link = a_tag['href']
            print(title, link)
    else:
        # 응답(response)이 Error 이면 status code 출력  
        print(f'Error code = {res.status_code}')

# %%
print_news('경제')
# Out:
# 경제 뉴스 https://news.naver.com/section/101
# 비트코인, 3년 만에 '최악의 한주'…왜? 분석들 보니 https://n.news.naver.com/mnews/article/374/0000491416
#  https://n.news.naver.com/mnews/article/comment/374/0000491416
# 설연휴 대출 만기·카드 대금 결제·공과금 납부는 19일로 연기 https://n.news.naver.com/mnews/article/056/0012121134
#  https://n.news.naver.com/mnews/article/comment/056/0012121134
# LG전자, 글로벌 사우스서 AI 홈·현지 특화 신제품 릴레이 공개 https://n.news.naver.com/mnews/article/277/0005718512
#  https://n.news.naver.com/mnews/article/comment/277/0005718512
# 국힘 “퇴직연금 기금화, 수익률 명분에 숨은 사적 재산권 침해 시도” https://n.news.naver.com/mnews/article/023/0003957787
#  https://n.news.naver.com/mnews/article/comment/023/0003957787
# 구윤철 “상속세 이탈설 근거 부족…검증 안 된 통계” https://n.news.naver.com/mnews/article/011/0004587898
#  https://n.news.naver.com/mnews/article/comment/011/0004587898
# 쿠팡 주춤하자 2위 경쟁 치열…레트로·멤버십 강화 https://n.news.naver.com/mnews/article/422/0000831585
#  https://n.news.naver.com/mnews/article/comment/422/0000831585
# 빗썸 “사고 당시 이용자에 2만원 지급”… 보상 시작 https://n.news.naver.com/mnews/article/366/0001141256
#  https://n.news.naver.com/mnews/article/comment/366/0001141256
# 비트코인, 7만달러대로 급반등… 3년 만에 최대 폭 https://n.news.naver.com/mnews/article/366/0001141159
#  https://n.news.naver.com/mnews/article/comment/366/0001141159
# 김정관 산업장관 "대한상의 가짜뉴스 엄정 대응"…행정조치 예고 https://n.news.naver.com/mnews/article/277/0005718518
#  https://n.news.naver.com/mnews/article/comment/277/0005718518
# 공정위, ‘계열사 누락’ 김준기 DB그룹 창업회장 검찰 고발 https://n.news.naver.com/mnews/article/025/0003501782
#  https://n.news.naver.com/mnews/article/comment/025/0003501782
# 돌려받지 못한 128억 행방은…버텨도 민사소송하면 반환 https://n.news.naver.com/mnews/article/057/0001934342
#  https://n.news.naver.com/mnews/article/comment/057/0001934342
# 가진 비트코인 175개뿐인데 62만개 뿌렸다…3500배 ‘돈 복사’ https://n.news.naver.com/mnews/article/081/0003615702
#  https://n.news.naver.com/mnews/article/comment/081/0003615702
# 전기차 대신 ESS…배터리3사 안방·북미서 ‘격돌 2라운드’ https://n.news.naver.com/mnews/article/028/0002790608
#  https://n.news.naver.com/mnews/article/comment/028/0002790608
# 코인거래소 지분 규제·전수조사 속도전…금주 당정 담판(종합) https://n.news.naver.com/mnews/article/018/0006215381
#  https://n.news.naver.com/mnews/article/comment/018/0006215381
# “투자 안하면 벼락거지라는데”…‘금 한 돈 100만원 시대’ 똑똑한 금·은·동 투자법 [투자360] https://n.news.naver.com/mnews/article/016/0002597710
#  https://n.news.naver.com/mnews/article/comment/016/0002597710
# 임광현 국세청장이 직접 밝힌 '부유층 해외이탈'의 진실 https://n.news.naver.com/mnews/article/047/0002504287
#  https://n.news.naver.com/mnews/article/comment/047/0002504287
# 2000원 주려다 2000BTC… ‘유령 코인’ 61조 만들어 뿌렸다 https://n.news.naver.com/mnews/article/022/0004104306
#  https://n.news.naver.com/mnews/article/comment/022/0004104306
# '패닉셀' 이어진 빗썸 비트코인 오지급… "저가 매도 110% 보상" https://n.news.naver.com/mnews/article/469/0000913468
#  https://n.news.naver.com/mnews/article/comment/469/0000913468
# [단독] "노력 도둑맞았다"…두쫀쿠 원조 논란에 '본인 등판' https://n.news.naver.com/mnews/article/015/0005248492
#  https://n.news.naver.com/mnews/article/comment/015/0005248492
# ‘2배 베팅’ 몰리는 개미... 1월에만 15만명 가세 https://n.news.naver.com/mnews/article/014/0005475173
#  https://n.news.naver.com/mnews/article/comment/014/0005475173
# 증시 '위험한 베팅' 절반은 3040세대… 10대도 3배 급증 https://n.news.naver.com/mnews/article/014/0005475165
#  https://n.news.naver.com/mnews/article/comment/014/0005475165
# 용산국제업무지구에 '닭장 아파트' 라니…'1만가구' 가구당 면적, 2인 최저기준보다 좁아  [1·29 대책 '후폭풍'] https://n.news.naver.com/mnews/article/014/0005475161
#  https://n.news.naver.com/mnews/article/comment/014/0005475161
# 李 격노에 경제 수장들 “대한상의 가짜뉴스 엄벌” 십자포화 https://n.news.naver.com/mnews/article/081/0003615696
#  https://n.news.naver.com/mnews/article/comment/081/0003615696
# 한동훈 "제 풀에 꺾여 그만둘 기대 접으라···역전승 시작하자" https://n.news.naver.com/mnews/article/050/0000102048
#  https://n.news.naver.com/mnews/article/comment/050/0000102048
# 곧 중국산 HBM3 양산…한중격차 4년서 3년으로 좁혀졌다 https://n.news.naver.com/mnews/article/009/0005634234
#  https://n.news.naver.com/mnews/article/comment/009/0005634234
# ‘대형 악재’ 없는데 추락하는 암호화폐… 혹한기 길어질듯 https://n.news.naver.com/mnews/article/014/0005475155
#  https://n.news.naver.com/mnews/article/comment/014/0005475155
# 납기·사후지원·기술이전 '삼박자'… 동남아도 韓무기 러브콜 https://n.news.naver.com/mnews/article/014/0005475153
#  https://n.news.naver.com/mnews/article/comment/014/0005475153
# 비트코인, 7만달러 고지전 돌입… ‘검은 목요일’ 재연될까 긴장 [주간 블록체인] https://n.news.naver.com/mnews/article/138/0002217461
#  https://n.news.naver.com/mnews/article/comment/138/0002217461
# "장 좋아도 불안해"…VIX 콜옵션 투자 급증 https://n.news.naver.com/mnews/article/014/0005475146
#  https://n.news.naver.com/mnews/article/comment/014/0005475146
# 코스피 흔들려도 상승 베팅…개인 '초단기 빚투' 역대최대 https://n.news.naver.com/mnews/article/014/0005475141
#  https://n.news.naver.com/mnews/article/comment/014/0005475141
# "에틸렌 만들면 손해"… 석화업계 깊은 한숨 https://n.news.naver.com/mnews/article/014/0005475139
#  https://n.news.naver.com/mnews/article/comment/014/0005475139
# 中 저가공습 맞서는 SK온 "EV배터리 값 낮추고 경량화" https://n.news.naver.com/mnews/article/014/0005475138
#  https://n.news.naver.com/mnews/article/comment/014/0005475138
# 금융·고배당 테마 강세… 美 AI·미래기술 ETF는 '출렁' [ETF 스퀘어] https://n.news.naver.com/mnews/article/014/0005475135
#  https://n.news.naver.com/mnews/article/comment/014/0005475135
# 60대 가장 "집 사려는 아들에게 증여세 없이 5억 빌려줄 수 있을까" [세무 재테크 Q&A] https://n.news.naver.com/mnews/article/014/0005475134
#  https://n.news.naver.com/mnews/article/comment/014/0005475134
# 실물 없이 장부로 무제한 거래…유령 코인 사태 언제든 재발 가능 https://n.news.naver.com/mnews/article/018/0006215366
#  https://n.news.naver.com/mnews/article/comment/018/0006215366
# "대기업이 HBM 집중할때, 틈새 메모리 시장 주도" [C리즈] https://n.news.naver.com/mnews/article/014/0005475123
#  https://n.news.naver.com/mnews/article/comment/014/0005475123
# 큰손 떠나는 서울 오피스… CBD 공실률 최대 10%대 경고 https://n.news.naver.com/mnews/article/014/0005475111
#  https://n.news.naver.com/mnews/article/comment/014/0005475111
# 미보유 코인 60조 살포, 내부통제는 없었다 https://n.news.naver.com/mnews/article/018/0006215365
#  https://n.news.naver.com/mnews/article/comment/018/0006215365
# 정부가 이길까, 시장이 이길까… 전세계 다주택자 잔혹사 [글로벌 리포트] https://n.news.naver.com/mnews/article/014/0005475094
#  https://n.news.naver.com/mnews/article/comment/014/0005475094
# 김용범 “‘국장 탈출은 지능순’ 단순 유행어 아냐…청년 분노 응축” https://n.news.naver.com/mnews/article/020/0003695852
#  https://n.news.naver.com/mnews/article/comment/020/0003695852
# “1척 팔면 톤세 혜택 끊길 판… 케미컬선 총톤수 기준 낮춰야” https://n.news.naver.com/mnews/article/082/0001366163
#  https://n.news.naver.com/mnews/article/comment/082/0001366163
# 빗썸 오지급 보상 "비트코인으로 돌려달라"...'장부 거래' 파장 계속 https://n.news.naver.com/mnews/article/052/0002312051
#  https://n.news.naver.com/mnews/article/comment/052/0002312051
# 레버리지 ETF에 뛰어드는 개미들…일주일간 7000억 ‘사자’ https://n.news.naver.com/mnews/article/011/0004588049
#  https://n.news.naver.com/mnews/article/comment/011/0004588049
# 4%대 수익도 성에 안차…“2~3년 돈 묻어두느니 국장으로” [불장에 찬밥된 IMA] https://n.news.naver.com/mnews/article/011/0004588048
#  https://n.news.naver.com/mnews/article/comment/011/0004588048
# 에코프로비엠, 실적 반등에도 엇갈린 평가…“회복 초입”vs“기대 선반영” https://n.news.naver.com/mnews/article/018/0006215359
#  https://n.news.naver.com/mnews/article/comment/018/0006215359
# '5천피 시대' 4799조원 '껑충'…K-시총, 독일·대만도 제꼈다 https://n.news.naver.com/mnews/article/243/0000092741
#  https://n.news.naver.com/mnews/article/comment/243/0000092741

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

# 육아일기 73회차
req_header = {
    'referer':'https://comic.naver.com/webtoon/detail?titleId=812354&no=208&week=sun',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
}

img_urls = [
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/812354/208/20251223155029_0d14a9e6cdd6b23342f96d1bd33d01c3_IMAG01_3.jpg'
]

for img_url in img_urls:
    # requests 의 get(url, headers) 함수 호출하기 
    res = requests.get(img_url, headers=req_header)
    print(res.status_code)        
    # binary 응답 데이터 가져오기
    img_data = res.content    
    # url에서 파일명만 추출하기
    file_name = os.path.basename(img_url)
    print(file_name)        
    # binday data를 file에 write하기
    with open(file_name,'wb') as file:
        print(f'Writing to {file_name}({len(img_data):,} bytes)')
        file.write(img_data)

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %%
import requests
from bs4 import BeautifulSoup
import os

webtoon_url = 'https://comic.naver.com/webtoon/detail?titleId=812354&no=208&week=thu'

req_header = {
    'referer':webtoon_url,
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
}

res = requests.get(webtoon_url, headers=req_header)
if res.ok:
    # .jpg 파일명을 추출해서 list에 저장하기
    soup = BeautifulSoup(res.text, 'html.parser')
    print(len(soup.select("img[src*='IMAG01']")))
    img_tags = soup.select("img[src*='IMAG01']")
    
    # img_url_list = [] #list()
    # for img_tag in img_tags:
    #     img_url = img_tag['src']
    #     img_url_list.append(img_url)
        
    # List Comprehension
    img_url_list2 = [img_tag['src'] for img_tag in img_tags]
    print(img_url_list2[:2])

    imgdir_name = 'img'
    if not os.path.isdir(imgdir_name):
        os.mkdir(imgdir_name)

    for img_url in img_url_list2:
        # requests 의 get(url, headers) 함수 호출하기 
        res = requests.get(img_url, headers=req_header)      
        # binary 응답 데이터 가져오기
        img_data = res.content    
        #img/xxxIMG01.jpg
        file_path = os.path.join(imgdir_name,os.path.basename(img_url))        
        # binday data를 file에 write하기
        with open(file_path,'wb') as file:
            print(f'Writing to {file_path}({len(img_data):,} bytes)')
            file.write(img_data)
else:
    print(f'Error code = {res.status_code}')

# %% [markdown]
# ### 리팩토링 된 코드

# %%
import requests
from bs4 import BeautifulSoup
import os

# 기본 설정
url = 'https://comic.naver.com/webtoon/detail?titleId=833255&no=3&week=tue'
req_header = {'referer': url}
imgdir_name = 'img'

# 이미지 저장 폴더가 없으면 생성
os.makedirs(imgdir_name, exist_ok=True)

# 웹 페이지 요청 및 확인
res = requests.get(url)
if not res.ok:
    print(f'Error Code = {res.status_code}')
    exit()

# 이미지 URL 추출
soup = BeautifulSoup(res.text, 'html.parser')
img_url_list = [img_tag['src'] for img_tag in soup.select("img[src*='IMAG01']")]

# 이미지 다운로드
for img_url in img_url_list:
    res = requests.get(img_url, headers=req_header)
    if res.ok:
        img_data = res.content
        file_path = os.path.join(imgdir_name, os.path.basename(img_url))
        with open(file_path, 'wb') as file:
            print(f'Writing to {file_path} ({len(img_data):,} bytes)')
            file.write(img_data)
    else:
        print(f'Error Code = {res.status_code} for {img_url}')

# %% [markdown]
# ### 3. 파일 업로드 하기
# * https://httpbin.org/
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    'img1': open('img/f1.jpg','rb'),
    'img2': open('img/f2.jpg','rb')
}
#print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.
res = requests.post(url, files=upload_files)
print(res.status_code)
print(res.json()['files']['img1'])

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
from dotenv import load_dotenv
import os
load_dotenv()

CLIENT_ID = os.getenv("CLIENT_ID")
print(CLIENT_ID[:4])

CLIENT_SECRET = os.getenv("CLIENT_SECRET")
print(CLIENT_SECRET[:4])

# %%
# 캡차 키 발급 요청
import urllib.request

code = "0"
url = "https://openapi.naver.com/v1/captcha/nkey?code=" + code
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",CLIENT_ID)
request.add_header("X-Naver-Client-Secret",CLIENT_SECRET)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

# %%
# 캡차 이미지 요청
import urllib.request

key = "pPvy7C2VTDFa4Vo7" # 캡차 Key 값
url = "https://openapi.naver.com/v1/captcha/ncaptcha.bin?key=" + key
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",CLIENT_ID)
request.add_header("X-Naver-Client-Secret",CLIENT_SECRET)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    print("캡차 이미지 저장")
    response_body = response.read()
    with open('img/captcha.jpg', 'wb') as f:
        f.write(response_body)
else:
    print("Error Code:" + rescode)

# %%
#  사용자 입력값 검증 요청
import requests

code = "1"
key = "pPvy7C2VTDFa4Vo7"
value = "2S5EC"
req_header = {
    "X-Naver-Client-Id": CLIENT_ID,
    "X-Naver-Client-Secret": CLIENT_SECRET
}

req_param = {
    "code": code,
    "key": key,
    "value": value
}
url = "https://openapi.naver.com/v1/captcha/nkey"

try:
    res = requests.get(url, headers=req_header, params=req_param)
    #4xx,5xx 오류가 발생하면 예외 발생시킴
    res.raise_for_status

    print(res.text)
except requests.exceptions.RequestException as e:
    print(f'Status Code : {res.status_code}')
    print(f'Error 발생 : {e}')

# %% [markdown]
# * requests를 사용하는 코드로 변경하기
# * [requests docs](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %% [markdown]
# ### 5. 블로그 검색하기

# %%
import requests
from pprint import pprint

headers = {
    'X-Naver-Client-Id': CLIENT_ID,
    'X-Naver-Client-Secret': CLIENT_SECRET
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'


# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)
# json() 함수로 응답 결과 가져오오기 [{},{},{}]
print(len(res.json()['items'])) 
pprint(res.json()['items'])

items_data = res.json()['items']
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# 'data/nhnblog.txt' 파일 생성하기
# Out:
# 100
# [{'bloggerlink': 'blog.naver.com/blackhole_chinese',
#   'bloggername': '묘한 교육 연구소',
#   'description': '<b>파이썬</b> 자격증 시험 종류 및 공부방법 취득후기 <b>파이썬</b> 자격증 취득자의 후기를 '
#                  '소개합니다. 처음부터 개발자가 되고 싶은 건 아니었어요! 취업을 준비하다 보니 자연스레 눈길이 갔죠! '
#                  '문과로는 도무지... ',
#   'link': 'https://blog.naver.com/blackhole_chinese/224107596612',
#   'postdate': '20251212',
#   'title': '<b>파이썬</b> 자격증 시험 종류 및 공부방법 취득후기'},
#  {'bloggerlink': 'blog.naver.com/ureka310',
#   'bloggername': '아빠 집으로 가는 길',
#   'description': '단순 대전<b>파이썬</b>학원 대전자바학원처럼 단과 과정이 아닌, 취업을 목적으로 하는 IT 실무 기술을 '
#                  '배우는... 대전<b>파이썬</b>학원과 대전자바학원처럼 하나의 언어만 배우는 것이 아니라 여러 기술을 '
#                  '종합적으로... ',
#   'link': 'https://blog.naver.com/ureka310/224120952595',
#   'postdate': '20251224',
#   'title': '대전<b>파이썬</b>학원 자바 실무 중심 대전IT학원'},
#  {'bloggerlink': 'blog.naver.com/anycall2502',
#   'bloggername': '더불어 사는 세상 이도형',
#   'description': '<b>파이썬</b>전문가 자격증 종류, 효율적인 취득방법 <b>파이썬</b>은 데이터 분석, 웹 개발, '
#                  '인공지능, 백엔드 등 다양한 분야에서 널리 쓰이는 인기 프로그래밍 언어로 요즘 시대에 필요한 역량이었어요. '
#                  '저는 컴퓨터... ',
#   'link': 'https://blog.naver.com/anycall2502/224099437736',
#   'postdate': '20251205',
#   'title': '<b>파이썬</b>전문가 자격증 종류, 효율적인 취득방법'},
#  {'bloggerlink': 'blog.naver.com/lmwu123',
#   'bloggername': '쉼표, 느낌표',
#   'description': '특히 <b>파이썬</b>은 입문자도 배우기 좋고 활용 범위가 넓다는 말이 많아서 고민 끝에 인천코딩학원을 '
#                  '찾다가 집 근처에 있는 우리컴퓨터아카데미 부평캠퍼스에서 <b>파이썬</b> 입문 과정을 운영 중이라기에 바로 '
#                  '상담받고... ',
#   'link': 'https://blog.naver.com/lmwu123/224120114156',
#   'postdate': '20251223',
#   'title': '인천코딩학원 <b>파이썬</b> 입문 성공한 후기'},
#  {'bloggerlink': 'blog.naver.com/songin06',
#   'bloggername': '소소한 일상?',
#   'description': '그렇게 실무 중심으로 진행되는 <b>파이썬</b> 기반 AI 프로젝트 수업을 듣기로 결정하게 되었어요. '
#                  '수업을... 해당 수업과정에서는 빅데이터나 AI 기반에 중요한 비중을 차지하는 언어인 <b>파이썬</b>을 '
#                  '기초부터 학습한 뒤... ',
#   'link': 'https://blog.naver.com/songin06/224072643572',
#   'postdate': '20251112',
#   'title': '인천AI국비지원 <b>파이썬</b> 기반 실무 중심 커리큘럼'},
#  {'bloggerlink': 'blog.naver.com/togyu911',
#   'bloggername': 'IIS 지식정보네트워크',
#   'description': '<b>파이썬</b>자격증 취업 장소 및 공부방법 제가 공부한 솔직한 후기를 바탕으로 작성되었어요! IT '
#                  '코딩... 코딩을 공부하기로 결심한 후에는 어디서부터 학습하면 되는지를 자세히 알아보았고 '
#                  '<b>파이썬</b>을... ',
#   'link': 'https://blog.naver.com/togyu911/223954106266',
#   'postdate': '20250731',
#   'title': '<b>파이썬</b>자격증 취업 장소 및 공부방법'},
#  {'bloggerlink': 'blog.naver.com/smgong00',
#   'bloggername': '지혜를 여는 부엉이상점',
#   'description': '<b>파이썬</b>(Python)이에요. 데이터 분석, 머신러닝, 딥러닝, 생성형 AI까지 하나의 언어로 '
#                  '이어지기 때문에 비전공자분들도 비교적 수월하게 입문할 수 있다는 강점이 있죠. 그래서 요즘 취준생 사이에서 '
#                  '<b>파이썬</b>... ',
#   'link': 'https://blog.naver.com/smgong00/224136151038',
#   'postdate': '20260106',
#   'title': '<b>파이썬</b> 국비지원 받는 방법; 대상 여부와 생성형 AI 학원 대표... '},
#  {'bloggerlink': 'blog.naver.com/naraebaragi',
#   'bloggername': 'Leather',
#   'description': '<b>파이썬</b> 관련 자격증 종류 및 취득방법 AI 잘 활용할 줄 아시나요? 4차산업혁명 시작 이후 AI '
#                  '능력이... 특히 쉽고 직관적으로 활용 가능한 코팅 툴인 <b>파이썬</b>(Python)에 대한 관심이 '
#                  '뜨겁습니다. 비전공자도 쉽게... ',
#   'link': 'https://blog.naver.com/naraebaragi/224082435190',
#   'postdate': '20251120',
#   'title': '<b>파이썬</b> 관련 자격증 종류 및 취득방법 정리'},
#  {'bloggerlink': 'blog.naver.com/likesonny',
#   'bloggername': '진상의 추억',
#   'description': '오늘은 그중에서도 <b>파이썬</b>에 관해 이야기하려고 하는데요. 비전공자분들을 위한 <b>파이썬</b> '
#                  '자격증 시험 정보부터 일정 취득방법을 정리해보도록 하겠습니다. 코딩에 관심 있는 분들은 한번 읽어보시길 '
#                  '바랍니다!... ',
#   'link': 'https://blog.naver.com/likesonny/224042372114',
#   'postdate': '20251015',
#   'title': '<b>파이썬</b> 자격증 시험 정보 및 일정 취득방법 정리'},
#  {'bloggerlink': 'blog.naver.com/krogue1004',
#   'bloggername': '모니토리 IT 이야기',
#   'description': '<b>파이썬</b> 설치할 때 &quot;PATH 체크&quot; 깜빡했다면? 1분 만에 수습하는 법 '
#                  '안녕하세요. 생활 아이티 활용 블로거 모니토리입니다. 바이브 코딩을 준비하면서 격었던 <b>파이썬</b> '
#                  '설치시 주의 하라고 했던 &quot;PATH 체크... ',
#   'link': 'https://blog.naver.com/krogue1004/224111011437',
#   'postdate': '20251216',
#   'title': '<b>파이썬</b> 설치할 때 &quot;PATH 체크&quot; 깜빡했다면? 1분 만에 수습하는... '},
#  {'bloggerlink': 'blog.naver.com/itbank21c',
#   'bloggername': 'KG에듀원 아이티뱅크 공식블로그',
#   'description': '누구는 <b>파이썬</b>이 쉽다 하고, 누구는 자바가 중요하다고 하고, 또 어디서는 C언어가 '
#                  '기본이라고... C언어, <b>파이썬</b>, 자바, 리눅스, HTML/CSS 이 다섯 가지예요. 이 '
#                  '과목들이 자주 등장하는 이유는 단순해요. 화려한... ',
#   'link': 'https://blog.naver.com/itbank21c/224112712269',
#   'postdate': '20251217',
#   'title': 'IT 입문자 1순위 과목 정리 | C언어·<b>파이썬</b>·자바(JAVA)... '},
#  {'bloggerlink': 'blog.naver.com/icbanq',
#   'bloggername': 'No.1 전자엔지니어 전문몰 아이씨뱅큐',
#   'description': '<b>파이썬</b>과 마이크로비트로 배우는 실전 코딩 프로젝트 교재 코알딩 18,900 안녕하세요~ '
#                  "나도메이커입니다 '<b>파이썬</b>과 마이크로비트로 배우는 실전 코딩' 세 번째 시간입니다! 오늘의 주제는 "
#                  "'미세먼지... ",
#   'link': 'https://blog.naver.com/icbanq/224118354325',
#   'postdate': '20251222',
#   'title': '<b>파이썬</b>&amp;마이크로비트로 배우는 실전코딩 | #3. 미세먼지 알리미... '},
#  {'bloggerlink': 'blog.naver.com/yejac4747',
#   'bloggername': '카리스마',
#   'description': '비트코인 자동매매 <b>파이썬</b> 코드 예시 초보 ✅투세븐빗 거래소 국내 독점 수수료 '
#                  '0.01%(지정가)... <b>파이썬</b>을 이용한 자동매매의 기본 개념 <b>파이썬</b>은 데이터 '
#                  '과학과 인공지능 분야에서 널리 사용되는 프로그래밍... ',
#   'link': 'https://blog.naver.com/yejac4747/223971292280',
#   'postdate': '20250815',
#   'title': '비트코인 자동매매 <b>파이썬</b> 코드 예시 초보'},
#  {'bloggerlink': 'blog.naver.com/ishkkman',
#   'bloggername': 'A.I Researcher - Ph.D 인공지능교육',
#   'description': '<b>파이썬</b> 수학과학 AI융합수업 소개 및 필요성 아래 내용은 NCIC 국가교육과정정보센터에서 '
#                  '제공하고 있는... 말씀드리는 <b>파이썬</b>과 수학과학 융합수업은 위와 같은 실제 학교에서 수업하는 '
#                  '수학교과과정에 <b>파이썬</b>... ',
#   'link': 'https://blog.naver.com/ishkkman/224167020627',
#   'postdate': '20260201',
#   'title': '압구정코딩학원 <b>파이썬</b>으로 수학과학 AI융합수업 만족도최고'},
#  {'bloggerlink': 'blog.naver.com/soary81',
#   'bloggername': '소라윙즈의 소소한 IT/게임 리뷰',
#   'description': '그래서 오늘은 AI 코딩에 관심 있는 <b>파이썬</b> 입문자 분들을 위해 기념 개념과 함께 프롬프트 '
#                  '작성... 10년 간 개발자 생활을 한 경력이 있다 보니까 AI <b>파이썬</b> 강의를 듣고 프롬프트 '
#                  '사용법만 익히고 나면 1인... ',
#   'link': 'https://blog.naver.com/soary81/224131607417',
#   'postdate': '20260102',
#   'title': 'AI 코딩밸리 <b>파이썬</b> 입문자를 위한 ai 강의 후기'},
#  {'bloggerlink': 'https://kwangho.tistory.com/',
#   'bloggername': '엔돌슨의 IT이야기',
#   'description': '<b>파이썬</b>으로 배우는 AI 에이전트 개발 입문 서적 추천! 밑바닥부터 배우는 LLM 활용법 '
#                  '안녕하세요... 프레임워크가 숨겨둔 추상화 계층을 걷어내고 <b>파이썬</b> 기본 코드와 API 호출만으로 '
#                  '에이전트의 논리... ',
#   'link': 'https://kwangho.tistory.com/531753',
#   'postdate': '20251219',
#   'title': '<b>파이썬</b>으로 배우는 AI 에이전트 개발 입문 서적 추천!... '},
#  {'bloggerlink': 'blog.naver.com/urmyver',
#   'bloggername': '주들의 그리 대단하진 않지만 굉장한 이야기',
#   'description': '자바 개발자 <b>파이썬</b>을 알아야 하는가에 대한 고찰 많고 많은 프로그래밍 언어들 중에서 가장 '
#                  '많이... 다만, 근래에는 자바보다 <b>파이썬</b>의 가치가 높다고 주장하는 사람들이 많아졌고, 현재의 '
#                  'IT 시장을 선도하고... ',
#   'link': 'https://blog.naver.com/urmyver/224147726522',
#   'postdate': '20260115',
#   'title': '자바 개발자 : <b>파이썬</b>을 알아야 하는가에 대한 고찰'},
#  {'bloggerlink': 'blog.naver.com/ifnotnow_thenwhen',
#   'bloggername': 'MJ의 방방곡곡',
#   'description': '초등학생 <b>파이썬</b>독학용 책으로 공부해보기로 했는데요. 초등학생, 중학생 등 코딩을 처음 접하는 '
#                  '어린이도 쉽게 배울 수 있다는 &quot;똑똑한 <b>파이썬</b>&quot;을 선택해봤는데요. 어떤 '
#                  '내용으로 구성되어 있고, 얼마나 쉽고... ',
#   'link': 'https://blog.naver.com/ifnotnow_thenwhen/224173331067',
#   'postdate': '20260206',
#   'title': '초등학생 독학용 <b>파이썬</b>책추천 똑똑한 <b>파이썬</b> 내용 구성 후기'},
#  {'bloggerlink': 'blog.naver.com/rrewazxc',
#   'bloggername': '시원한 파랑_"시작하시죠, 파란만장한 컴퓨터 인생"',
#   'description': '기술적으로 접근하면 AI나 주식투자나 증권에 관심있는 사람들은 이미 <b>파이썬</b>을 배우거나 '
#                  '생성형... 성남<b>파이썬</b>학원의 교육과정을 알아보겠습니다. 데이터분석, AI에 대한 학습과정이 '
#                  '짧게는 1-2개월... ',
#   'link': 'https://blog.naver.com/rrewazxc/224171591873',
#   'postdate': '20260204',
#   'title': '성남<b>파이썬</b>학원 기초, 데이터분석 1-2개월학습 (저녁/주말)'},
#  {'bloggerlink': 'blog.naver.com/smgong00',
#   'bloggername': '지혜를 여는 부엉이상점',
#   'description': '자연스럽게 <b>파이썬</b>학원을 찾게 되죠. 주변에서 공통적으로 말하기 때문이에요. &quot;인공지능을 '
#                  '배우고 싶다면 Python이 첫걸음이다.&quot; 자세히 알아보면 생성형 AI든 데이터 분석이든 대부분 '
#                  '<b>파이썬</b> 기반이라... ',
#   'link': 'https://blog.naver.com/smgong00/224105718323',
#   'postdate': '20251211',
#   'title': '종로 <b>파이썬</b>학원: 생성형 AI 개발과 취업까지 올인원 가능한 곳'},
#  {'bloggerlink': 'blog.naver.com/nce0623',
#   'bloggername': '에릭의 IT스토리',
#   'description': '그래서 오늘은 초보자가 가장 접근하기 쉽다는 <b>파이썬</b>(Python) 독학에 대해 이야기해보려고 '
#                  '해요. &quot;과연 혼자서 될까?&quot; 고민 중이라면 오늘 글을 끝까지 읽어주세요! 왜 하필 '
#                  '<b>파이썬</b>(Python)일까? 많은 개발자와... ',
#   'link': 'https://blog.naver.com/nce0623/224121210068',
#   'postdate': '20251224',
#   'title': '<b>파이썬</b>(Python) 문과생도, 비전공자도 OK! 파이선 프로그래밍... '},
#  {'bloggerlink': 'blog.naver.com/haksjy91',
#   'bloggername': '서울에 사는 한 여자',
#   'description': '특히 <b>파이썬</b> 자격증이 비전공자와 초보자뿐만 아니라 전문가에도 중요한 라이선스로 인정받고... '
#                  '오늘은 <b>파이썬</b> 자격증 시험 정보 및 취득방법을 알려드리겠습니다! 1. <b>파이썬</b> 자격증 '
#                  '시험이란? <b>파이썬</b>... ',
#   'link': 'https://blog.naver.com/haksjy91/224001710519',
#   'postdate': '20250909',
#   'title': '<b>파이썬</b> 자격증 시험 정보 및 취득방법'},
#  {'bloggerlink': 'blog.naver.com/keiraso',
#   'bloggername': '테크헌터 IT 팩토리',
#   'description': "<b>파이썬</b> 뜻 코딩 독학 현실 후기 대학생 때 처음 '프로그래밍'이라는 단어를 들었을 땐 막연히 "
#                  '어렵고... 취업, 이직, 생산성 향상, 자동화… 다양한 이유로 <b>파이썬</b> 독학을 시작하는 분들이 '
#                  '정말 많아졌어요. 저도... ',
#   'link': 'https://blog.naver.com/keiraso/224124706635',
#   'postdate': '20251227',
#   'title': '<b>파이썬</b> 뜻 코딩 독학 현실 후기'},
#  {'bloggerlink': 'blog.naver.com/tokyomari',
#   'bloggername': 'WORKS ON WEB & JP CULTURE',
#   'description': '<b>파이썬</b>(Python)은 지금 전 세계에서 가장 많이 쓰이는 프로그래밍 언어 중 하나입니다. '
#                  '그런데... 사실 요즘은 설치 없이 웹에서 바로 <b>파이썬</b>을 실행할 수 있는 방법이 정말 많아요. '
#                  '오늘은 초보자도... ',
#   'link': 'https://blog.naver.com/tokyomari/224048175781',
#   'postdate': '20251021',
#   'title': '<b>파이썬</b> 설치 없이 웹에서 바로 실행하기! 초보자도 쉽게 배우는... '},
#  {'bloggerlink': 'blog.naver.com/djusti',
#   'bloggername': '버들붕어 스토리',
#   'description': '<b>파이썬</b> 프로그래밍, 그 인기가 계속되는 이유는? 프로그래밍 언어는 셀 수 없이 많지만, '
#                  '<b>파이썬</b> 프로그래밍은 여전히 수많은 개발자들이 선택하는 언어입니다. 그 이유는 간결한 문법과 빠른 '
#                  '생산성, 넓은... ',
#   'link': 'https://blog.naver.com/djusti/224136310898',
#   'postdate': '20260106',
#   'title': '<b>파이썬</b> 프로그래밍, 왜 PYTHON 계속해서 주목받는 언어일까?'},
#  {'bloggerlink': 'blog.naver.com/koreatech91',
#   'bloggername': '한국기술교육대학교 공식 블로그',
#   'description': '바로 ‘<b>파이썬</b>(Python)’을 소개해드리려고 합니다.  <b>파이썬</b>은 어떤 언어일까? '
#                  '<b>파이썬</b>은 ‘사람이 읽기 쉬운 언어’를 목표로 만들어졌습니다. 그래서 문법이 단순하고 직관적이죠. '
#                  '영어 문장을 읽듯... ',
#   'link': 'https://blog.naver.com/koreatech91/224082220895',
#   'postdate': '20251121',
#   'title': '<b>파이썬</b>은 쉽습니다!ㅣ<b>파이썬</b>으로 기초부터 AI까지'},
#  {'bloggerlink': 'blog.naver.com/krogue1004',
#   'bloggername': '모니토리 IT 이야기',
#   'description': '<b>파이썬</b> 설치, 겁먹지 마세요! &quot;체크박스 하나&quot;면 끝납니다 안녕하세요!! 생활 '
#                  '아이티 활용 블로거... 이건 어떻게 <b>파이썬</b> 설치부터 막히는지 ^^;;; 자 제가 뭣때문에 이런 '
#                  '이야기를 하는지 그리고 어떻게 하면... ',
#   'link': 'https://blog.naver.com/krogue1004/224108304204',
#   'postdate': '20251213',
#   'title': '<b>파이썬</b> 다운로드 설치, 겁먹지 마세요! &quot;체크박스 하나&quot;면... '},
#  {'bloggerlink': 'blog.naver.com/sinnam88',
#   'bloggername': '포토그래퍼 신남의 IT세상',
#   'description': '오늘은 입문자분들을 위해 안정적인 경로로 파일을 받고 설정하는 <b>파이썬</b> 다운로드 설치 방법 '
#                  'python 버전 선택 에 대해 시작해보도록 할게요! 1. 공식 홈페이지를 이용한 <b>파이썬</b> '
#                  '다운로드 방법... ',
#   'link': 'https://blog.naver.com/sinnam88/224154449654',
#   'postdate': '20260121',
#   'title': '<b>파이썬</b> 다운로드 설치 방법 python 버전 선택'},
#  {'bloggerlink': 'blog.naver.com/codetree_',
#   'bloggername': '코드트리 공식 블로그',
#   'description': '그리고 지금 현시점, 그 기준이 되는 언어로 가장 많이 언급되는 것이 바로 '
#                  '<b>파이썬</b>(Python)이죠. 왜 AI 시대에 <b>파이썬</b>이 계속 선택되고 있을까요? '
#                  '<b>파이썬</b>이란 무엇인가 출처=TIOBE <b>파이썬</b>은 사람이 읽기 쉬운... ',
#   'link': 'https://blog.naver.com/codetree_/224161300022',
#   'postdate': '20260127',
#   'title': 'AI 시대, 왜 하필 <b>파이썬</b>일까 (비개발자도 배워야 하는 이유)'},
#  {'bloggerlink': 'blog.naver.com/urmyver',
#   'bloggername': '주들의 그리 대단하진 않지만 굉장한 이야기',
#   'description': '<b>파이썬</b> 기초, 입문은 독학으로 불가능한 건가? 컴퓨터(PC, 스마트폰 등)에서 실행할 수 '
#                  "있는... 이번 포스팅에선 프로그래밍 언어 중 입지가 아주 단단하기로 소문난 '<b>파이썬</b>'에 대해 "
#                  '알아보겠습니다. 1.... ',
#   'link': 'https://blog.naver.com/urmyver/224071152311',
#   'postdate': '20251110',
#   'title': '<b>파이썬</b> 기초, 입문은 독학으로 불가능한 건가?'},
#  {'bloggerlink': 'blog.naver.com/ilula',
#   'bloggername': 'ෆ 일상의 기록 ෆ',
#   'description': '<b>파이썬</b>에서 원하는 코딩을 입력하고 값을 출력해내려면 필요한 print 함수!!! 한마디로... '
#                  '송ha는 <b>파이썬</b>을 좋아해요. name = &quot;송ha&quot; age = 30 '
#                  'school = &quot;코딩대학교&quot; favorite = &quot;<b>파이썬</b>&quot; '
#                  '방법은 2가지!... ',
#   'link': 'https://blog.naver.com/ilula/224171840526',
#   'postdate': '20260204',
#   'title': '[<b>파이썬</b>] 기본 중의 기본, print 함수'},
#  {'bloggerlink': 'blog.naver.com/jaehyeon88',
#   'bloggername': 'Chaconne',
#   'description': '<b>파이썬</b> 설치부터 VS Code 세팅까지 완벽 가이드 (2025 최신 기준 · 입문자 전용) '
#                  '프로그래밍을 시작할 때 가장 먼저 준비해야 할 것은 <b>파이썬</b> 설치와 편리한 개발환경(IDE) '
#                  '구성입니다. 특히 VS... ',
#   'link': 'https://blog.naver.com/jaehyeon88/224078715024',
#   'postdate': '20251117',
#   'title': '<b>파이썬</b> 설치부터 VS Code 세팅까지 한번에 끝내기!!(초보 및... '},
#  {'bloggerlink': 'blog.naver.com/smgong00',
#   'bloggername': '지혜를 여는 부엉이상점',
#   'description': '<b>파이썬</b>교육, 기초만 배우고 끝낼 시대는 지났다 인공지능 기술이 빠르게 발전하면서 '
#                  '<b>파이썬</b>은 이제 개발자뿐 아니라 데이터·AI·자동화·콘텐츠 제작까지 다양한 분야에서 활용하는 '
#                  '언어가 됐어요. 그러면서... ',
#   'link': 'https://blog.naver.com/smgong00/224096422237',
#   'postdate': '20251203',
#   'title': '<b>파이썬</b>교육 기초부터 AI 프로젝트까지 전액지원 받는 과정'},
#  {'bloggerlink': 'blog.naver.com/futureworldz',
#   'bloggername': '미래세상',
#   'description': '<b>파이썬</b> 프로그램으로 코딩 쉽고 재미있게 배우기 <b>파이썬</b>은 간결하고 직관적인 문법을 '
#                  '갖춘 프로그래밍 언어로, 코딩을 처음 접하는 사람도 비교적 쉽게 접근할 수 있다는 장점이 있습니다. 다른 '
#                  '언어에 비해... ',
#   'link': 'https://blog.naver.com/futureworldz/224135461941',
#   'postdate': '20260105',
#   'title': '<b>파이썬</b> 프로그램으로 코딩 쉽고 재미있게 배우기'},
#  {'bloggerlink': 'blog.naver.com/itbankkr',
#   'bloggername': 'IT국비지원 – 왕초보에서 취업까지',
#   'description': '신촌 <b>파이썬</b> 국비지원 과정을 통해 코딩 초보자도 성공적으로 취업까지 나아갈 수 있는 현실적인 '
#                  '방법을 자세히 알려드리겠습니다. 여러분의 개발자 꿈, 더 이상 멀리 있지 않습니다. 왜 지금 '
#                  "'<b>파이썬</b>'을... ",
#   'link': 'https://blog.naver.com/itbankkr/224147691054',
#   'postdate': '20260115',
#   'title': '신촌<b>파이썬</b> 국비지원 취업까지! 코딩 초보도 걱정 마세요!'},
#  {'bloggerlink': 'blog.naver.com/ishkkman',
#   'bloggername': 'A.I Researcher - Ph.D 인공지능교육',
#   'description': '오늘은 컴퓨터 프로그래밍언어중 학생들이 많이 배우는 <b>파이썬</b>(Python), 자바(Java)를 왜 '
#                  '배워야하는지 그 이유에 대해서 소개해 드리려고 합니다. 강남코딩학원 프레임온 <b>파이썬</b> 자바 수업 '
#                  '교재... ',
#   'link': 'https://blog.naver.com/ishkkman/224144897900',
#   'postdate': '20260113',
#   'title': '강남코딩학원 <b>파이썬</b> 자바 왜 배워야하나'},
#  {'bloggerlink': 'blog.naver.com/alsl693',
#   'bloggername': 'ENTJ의 솔직한 일상',
#   'description': '[구름딥다이브] 점프 투 <b>파이썬</b> 5장 명령 프롬프트와 싸우며 배운 패키지와 예외처리 안녕하세요! '
#                  '오늘은 점프 투 <b>파이썬</b> 5장 3,4,5 를 공부했어요. Do it! 점프 투 <b>파이썬</b> '
#                  '박응용2023이지스퍼블리싱 패키지... ',
#   'link': 'https://blog.naver.com/alsl693/224145552241',
#   'postdate': '20260113',
#   'title': '[구름딥다이브] 점프 투 <b>파이썬</b> 5장 명령 프롬프트와 싸우며... '},
#  {'bloggerlink': 'blog.naver.com/kacnet',
#   'bloggername': '고려아카데미컨설팅',
#   'description': '한 달 만에 끝내는 AI·<b>파이썬</b>·디지털 역량 업그레이드 취업 준비가 점점 더 치열해지면서, '
#                  '대학생에게 꼭 필요한 스펙도 달라지고 있습니다. 이제는 단순 자격증보다 AI 활용 능력, <b>파이썬</b> '
#                  '기본기, 데이터... ',
#   'link': 'https://blog.naver.com/kacnet/224088594974',
#   'postdate': '20251126',
#   'title': '대학생 필수 스펙! 한 달 만에 끝내는 AI <b>파이썬</b> 디지털 역량'},
#  {'bloggerlink': 'blog.naver.com/cerans',
#   'bloggername': '.',
#   'description': '이번 시간에는 JavaScript 및 Java와 더불어 요즘 매우 핫한 프로그래밍 언어 중 하나인 '
#                  '<b>파이썬</b> 다운로드 및 <b>파이썬</b> 설치 방법에 대해 알아보겠습니다. 다른 언어에 비해 '
#                  '배우기가... ',
#   'link': 'https://blog.naver.com/cerans/224151916725',
#   'postdate': '20260119',
#   'title': '<b>파이썬</b> python 설치 및 다운로드 방법'},
#  {'bloggerlink': 'blog.naver.com/droplet7030',
#   'bloggername': '꽃은 죽어도 씨앗은 남는다고',
#   'description': '그중에서도 처음 언어로 <b>파이썬</b>을 알아보고 있었는데, 막상 <b>파이썬</b>책을 고르려니 너무 '
#                  '어렵고 두꺼운 책들만 보여서 선뜻 손이 안 가더라고요. 그러다 알게 된 게 바로 똑똑한 '
#                  '<b>파이썬</b>이에요. 처음 <b>파이썬</b>을... ',
#   'link': 'https://blog.naver.com/droplet7030/224119110418',
#   'postdate': '20251222',
#   'title': '<b>파이썬</b>책 추천 초등학생도 쉽게 따라가는 똑똑한 <b>파이썬</b>'},
#  {'bloggerlink': 'blog.naver.com/lordpark02',
#   'bloggername': '던창 해군 Herimon의 개인세계',
#   'description': '이렇게 반복 적인 작업 에는, <b>파이썬</b> 자동화 프로그램 하나로 의외로 간단히 해결할 수... '
#                  '그래서 <b>파이썬</b> 자동화 프로그램을 어떻게 활용을 하고 적용해야 되는지 예시를 살펴보면서... ',
#   'link': 'https://blog.naver.com/lordpark02/224022055635',
#   'postdate': '20250926',
#   'title': '<b>파이썬</b> 자동화 프로그램 개발 기초부터 익히려면?'},
#  {'bloggerlink': 'blog.naver.com/travelencyclopedia',
#   'bloggername': '여행백과사진',
#   'description': '<b>파이썬</b>이란? **<b>파이썬</b>(Python)**은 사람이 읽고 쓰기 쉬운 문법을 가진 고급 '
#                  '프로그래밍 언어야. 코드를 쓰는 느낌이 수식이나 문장에 가깝고, 그래서 배우는 속도가 빠르지 ✨ 핵심 한 '
#                  '줄... ',
#   'link': 'https://blog.naver.com/travelencyclopedia/224152331101',
#   'postdate': '20260119',
#   'title': '<b>파이썬</b>교육 #1'},
#  {'bloggerlink': 'blog.naver.com/urmyver',
#   'bloggername': '주들의 그리 대단하진 않지만 굉장한 이야기',
#   'description': '<b>파이썬</b> 프로그래밍 가장 좋은 입문 방법은? 필자가 처음 프로그래밍에 대해 관심을 갖고 '
#                  '학습을... 이번 포스팅에선 프로그래밍의 기초이자 핵심이라고 할 수 있는 프로그래밍 언어, '
#                  '<b>파이썬</b> 프로그래밍에 대해... ',
#   'link': 'https://blog.naver.com/urmyver/224155686212',
#   'postdate': '20260122',
#   'title': '<b>파이썬</b> 프로그래밍 가장 좋은 입문 방법은?'},
#  {'bloggerlink': 'blog.naver.com/grace202511',
#   'bloggername': '조용한 기록실',
#   'description': '지금 따끈하게 막 설치한 직후라 얼른 코딩을 해 보고 싶을 텐데요~ <b>파이썬</b>을 설치 하였으니... '
#                  '<b>파이썬</b> 실행하기 또는 설치 때 Add python.exe to PATH 옵션을 체크 했다면 '
#                  '작업표시줄에 검색창이 있다면 &quot;cmd... ',
#   'link': 'https://blog.naver.com/grace202511/224093709479',
#   'postdate': '20251201',
#   'title': '<b>파이썬</b> 기초 실습'},
#  {'bloggerlink': 'blog.naver.com/smgong00',
#   'bloggername': '지혜를 여는 부엉이상점',
#   'description': '<b>파이썬</b>프로그래밍 취업 준비, 아직도 웹 개발만 생각하시나요? <b>파이썬</b>프로그래밍은 '
#                  '문법은 직관적이고 활용 범위가 넓어 IT 취업에서 빠지지 않고 언급되는 언어에요. 비전공자도 접근하기 쉽고 '
#                  '전공자는... ',
#   'link': 'https://blog.naver.com/smgong00/224168666942',
#   'postdate': '20260202',
#   'title': '<b>파이썬</b>프로그래밍 취업 준비? 이 분야를 모르면 나만 손해!'},
#  {'bloggerlink': 'blog.naver.com/keukrae',
#   'bloggername': "keukrae's blog",
#   'description': '사전 준비 (라이브러리 설치) 이 코드를 실행하기 위해서는 아래의 <b>파이썬</b> 라이브러리들이... '
#                  '단순 반복 업무는 AI와 <b>파이썬</b>에게 맡기고, 우리는 더 가치 있는 엔지니어링 업무에 집중합시다! '
#                  '번역전... ',
#   'link': 'https://blog.naver.com/keukrae/224147550796',
#   'postdate': '20260115',
#   'title': '[업무 자동화] 중국어 PPT 주간보고, <b>파이썬</b>으로 1초... '},
#  {'bloggerlink': 'blog.naver.com/hactoefl',
#   'bloggername': '해커스 유학 블로그',
#   'description': '그중에서도 가장 인기 있는 언어가 바로 <b>파이썬</b>이에요! <b>파이썬</b>은 코딩을 처음 시작하는 '
#                  '분들도 쉽게 배울 수 있고 실무에서도 활용도가 높아서 입문자 + 실무자에게 모두 사랑받는 언어랍니다⭐ '
#                  '그래서... ',
#   'link': 'https://blog.naver.com/hactoefl/224056723753',
#   'postdate': '20251029',
#   'title': '<b>파이썬</b> 자격증 시험 합격 가이드 &amp; <b>파이썬</b> 강좌 추천'},
#  {'bloggerlink': 'blog.naver.com/itbankkr',
#   'bloggername': 'IT국비지원 – 왕초보에서 취업까지',
#   'description': '특히 접근성 좋은 종로에서 <b>파이썬</b> 국비지원을 통해 여러분의 개발자 꿈을 현실로 만들 수 있는 '
#                  "7가지... 개발자 꿈을 현실로 만드는 '종로 <b>파이썬</b> 국비지원'의 7가지 이유 1) "
#                  '<b>파이썬</b>의 압도적인 활용성으로 취업... ',
#   'link': 'https://blog.naver.com/itbankkr/224144729631',
#   'postdate': '20260113',
#   'title': '종로<b>파이썬</b> 국비지원, 개발자 꿈 현실로 만들 7가지 이유!'},
#  {'bloggerlink': 'blog.naver.com/clarkesquare',
#   'bloggername': 'Clarke Square',
#   'description': '모든 프로그래밍 언어들이 저마다 특징을 갖고 있지만, <b>파이썬</b> 하면 가장 크게 떠오르는 '
#                  '키워드들은... 특정 프로젝트 산출물 작성을 위해선 <b>파이썬</b>을 우선 배우는 편을 권장하고 '
#                  '있습니다. 기본기를 알고... ',
#   'link': 'https://blog.naver.com/clarkesquare/224169691149',
#   'postdate': '20260203',
#   'title': '만들면서 배우는 <b>파이썬</b> 프로젝트, 윤성필'},
#  {'bloggerlink': 'blog.naver.com/alsl693',
#   'bloggername': 'ENTJ의 솔직한 일상',
#   'description': '[구름딥다이브] 생성AI 미션 <b>파이썬</b> 객체지향 공부하기 with 점프투<b>파이썬</b> 5장 '
#                  '안녕하세요! Do it! 점프 투 <b>파이썬</b> 박응용 오늘은 제가 점프 투 <b>파이썬</b>으로 '
#                  '<b>파이썬</b> 객체지향을 공부하면서 배운 것을 기록해요!... ',
#   'link': 'https://blog.naver.com/alsl693/224144244683',
#   'postdate': '20260112',
#   'title': '생성AI 미션 <b>파이썬</b> 객체지향 공부하기 with 점프투<b>파이썬</b> 5장'},
#  {'bloggerlink': 'blog.naver.com/nce0623',
#   'bloggername': '에릭의 IT스토리',
#   'description': '<b>파이썬</b> 시작하려면 뭐부터 깔아야 해요? 이렇게 물으면 십중팔구 주피터 노트북과 아나콘다를 '
#                  '추천받을 겁니다. 그런데 막상 설치하려고 보면 conda는 뭐고 pip는 뭔지, 왜 그냥 '
#                  '<b>파이썬</b>이 아니라... ',
#   'link': 'https://blog.naver.com/nce0623/224137500330',
#   'postdate': '20260107',
#   'title': '<b>파이썬</b> 입문, 주피터 노트북과 아나콘다 완벽정리! (ft.... '},
#  {'bloggerlink': 'blog.naver.com/kacnet',
#   'bloggername': '고려아카데미컨설팅',
#   'description': '<b>파이썬</b>, 챗GPT, 데이터 시각화 등 관심은 넘치지만 막상 시작하면 어디서부터 어떻게 공부해야 '
#                  '할지... <b>파이썬</b> 독학은 자유롭고 비용이 적게 듭니다. 하지만 정보가 너무 많고, 체계적인 '
#                  '흐름이 부족합니다.... ',
#   'link': 'https://blog.naver.com/kacnet/224073237029',
#   'postdate': '20251112',
#   'title': '<b>파이썬</b> 독학 VS 실습 중심 강의, 실제 차이는?'},
#  {'bloggerlink': 'blog.naver.com/droplet7030',
#   'bloggername': '꽃은 죽어도 씨앗은 남는다고',
#   'description': '집에서도 오프라인 못지않게 몰입한 첫 코딩 수업 초등 <b>파이썬</b> 요즘 학교에서도 코딩이 필수 '
#                  '과목으로... 초등 <b>파이썬</b> 수업 관심 있으셨다면 꼭 읽어보셔야합니다~ 이 수업은 &lt;언제, '
#                  '어디서나, 원하는 선생님과... ',
#   'link': 'https://blog.naver.com/droplet7030/224060597800',
#   'postdate': '20251031',
#   'title': '돌핀코딩 초등 코딩화상수업 체험 후기 -<b>파이썬</b> 첫 수업'},
#  {'bloggerlink': 'blog.naver.com/here_papa',
#   'bloggername': '여행사 출신의 육아여행기',
#   'description': '비전공자의 첫 <b>파이썬</b> 도전기 똑똑한 <b>파이썬</b>을 택한 이유? 비전공자의 '
#                  '<b>파이썬</b> 도전기 첫 학습 시작 요즘 챗지피티부터 다양한 AI자동툴이 쏟아지고 있습니다. AI '
#                  '관련된 피드나 포스팅들을 한 번이라도... ',
#   'link': 'https://blog.naver.com/here_papa/224084814632',
#   'postdate': '20251123',
#   'title': '비전공자가 도전하는 똑똑한 <b>파이썬</b> 독학하기 추천도서'},
#  {'bloggerlink': 'blog.naver.com/urmyver',
#   'bloggername': '주들의 그리 대단하진 않지만 굉장한 이야기',
#   'description': '<b>파이썬</b>학원 단과 과정이 사라지고 있는 이유 프로그래밍 언어의 종류는 인간이 사용하는 언어의... '
#                  '예전에는 C, 자바 중 하나를 공부하는 경우가 많았으나, 현재에는 많고 많은 프로그래밍 언어 중 '
#                  '<b>파이썬</b>이란... ',
#   'link': 'https://blog.naver.com/urmyver/224104643589',
#   'postdate': '20251210',
#   'title': '<b>파이썬</b>학원 - 단과 과정이 사라지고 있는 이유'},
#  {'bloggerlink': 'blog.naver.com/travelencyclopedia',
#   'bloggername': '여행백과사진',
#   'description': '코딩할 때 쓰는 편집기 <b>파이썬</b>을 쓰기 가장 편한 도구 IDLE이 연습장이면, VS Code는 '
#                  '본게임... 5️⃣ <b>파이썬</b> 쓰려면 꼭 해야 할 것 ⭐ Python 확장 설치 왼쪽 네모 '
#                  '아이콘(확장) 클릭... ',
#   'link': 'https://blog.naver.com/travelencyclopedia/224154893381',
#   'postdate': '20260121',
#   'title': '<b>파이썬</b> 강의 #4'},
#  {'bloggerlink': 'blog.naver.com/grace202511',
#   'bloggername': '조용한 기록실',
#   'description': '(현재 제 컴퓨터 OS사양은 Windows 11 Pro입니다) 1.검색엔진에서 <b>파이썬</b> 공식 '
#                  '홈페이지(https://www.... 설치가 잘 되었는지 <b>파이썬</b> 프로그램을 확인 해 봅니다. '
#                  '아래 그림처럼 시작 → 모든 앱을... ',
#   'link': 'https://blog.naver.com/grace202511/224090682669',
#   'postdate': '20251128',
#   'title': '<b>파이썬</b> 설치하기'},
#  {'bloggerlink': 'blog.naver.com/zmfltmvlfhf2',
#   'bloggername': '1800-1773 컴스마일',
#   'description': '★소정의 원고료를 지원받고 작성 했습니다.★ AI개발자 국비지원 부트캠프 <b>파이썬</b> 기초 및 '
#                  '실무... 기초인 <b>파이썬</b>부터 서비스화까지 학습할 수 있는 코드잇 스프린트 AI 엔지니어 부트캠프 '
#                  '교육과정을... ',
#   'link': 'https://blog.naver.com/zmfltmvlfhf2/224095347725',
#   'postdate': '20251202',
#   'title': 'AI개발자 국비지원 부트캠프 <b>파이썬</b> 기초 및 실무 프로젝트 과정'},
#  {'bloggerlink': 'blog.naver.com/pwb5926',
#   'bloggername': '반짝이는 하루',
#   'description': '<b>파이썬</b> 뜻, 왜 다들 <b>파이썬</b> <b>파이썬</b> 할까요? 코딩 공부하려고 검색해보면 '
#                  '가장 먼저 보이는 이름, 바로 <b>파이썬</b>(Python)이죠? 무려 개발자들 사이에서 인기 순위 '
#                  '1위를 놓치지 않는 이 언어의 진짜 정체가... ',
#   'link': 'https://blog.naver.com/pwb5926/224169992171',
#   'postdate': '20260203',
#   'title': '<b>파이썬</b> 뜻과 특징? 코딩 입문자가 꼭 알아야 할 기초 정리'},
#  {'bloggerlink': 'blog.naver.com/supapa13',
#   'bloggername': '세수하면이병헌 IT/자동차',
#   'description': '✔️ <b>파이썬</b> 뜻은? ✔️ 독학 할만할까? <b>파이썬</b> 뜻은? <b>파이썬</b>은 '
#                  '1991년 귀도 반 로섬이 만든 프로그래밍 언어다. 배우기 쉬운 문법 구조를 가진 것이 특징이다. 현대 '
#                  '프로그래밍 세계에서 없어서는 안 될... ',
#   'link': 'https://blog.naver.com/supapa13/224113398577',
#   'postdate': '20251218',
#   'title': '<b>파이썬</b> 뜻, python 프로그래밍 독학 할만할까?'},
#  {'bloggerlink': 'blog.naver.com/grace202511',
#   'bloggername': '조용한 기록실',
#   'description': '<b>파이썬</b>을 하기 전에 알아두면 좋은 것들을 알아봅시다. 1. 프롬프트에 대하여 '
#                  '<b>파이썬</b>은 대화형 인터프리터 언어입니다. 처음 실행하면 아래 대화창과 같은 화면이 나타납니다. '
#                  '<b>파이썬</b> 실행 화면. 프롬프트... ',
#   'link': 'https://blog.naver.com/grace202511/224118374750',
#   'postdate': '20251222',
#   'title': '<b>파이썬</b> 시작 전 알아두면 좋은 것들'},
#  {'bloggerlink': 'blog.naver.com/itbankkr',
#   'bloggername': 'IT국비지원 – 왕초보에서 취업까지',
#   'description': "특히 '<b>파이썬</b>(Python)'은 문법이 간결하고 활용도가 높아 비전공자가 개발자로 입문하기에 "
#                  '가장 적합한... 내용 : <b>파이썬</b> 기초, 데이터 분석, 웹 프레임워크, 실무 프로젝트 4) 취업 '
#                  '분야 : 백엔드 개발자, 데이터... ',
#   'link': 'https://blog.naver.com/itbankkr/224151727694',
#   'postdate': '20260119',
#   'title': '안양<b>파이썬</b> 비전공자도 국비지원으로 IT 취업 성공하기'},
#  {'bloggerlink': 'blog.naver.com/dudrjtahdzl6',
#   'bloggername': '왕구렁이 블로그',
#   'description': 'pyhon 설치 <b>파이썬</b>을 설치합니다. '
#                  'https://www.python.org/downloads/ <b>파이썬</b> 홈페이지에 접속해서 '
#                  '다운받습니다! 노란색 박스 하단에 python 3.14.2 클릭 설치합니다. 하단에 보이는 체크박스 '
#                  'Add... ',
#   'link': 'https://blog.naver.com/dudrjtahdzl6/224125340126',
#   'postdate': '20251228',
#   'title': '<b>파이썬</b>으로 유튜브 댓글 추출하기 (ft. yt-dlp)'},
#  {'bloggerlink': 'blog.naver.com/13_11_16a',
#   'bloggername': '파푸리카',
#   'description': '오늘은 간단한 응용으로 <b>파이썬</b> 프로그램을 만들어보도록 하겠다. AI를 이용하면, 간단한 '
#                  '동작이... 그 다음 <b>파이썬</b>을 설치해준다. 매니저 설치 이후, 명령 프롬프트가 나와서 Y/N이 '
#                  '나올텐데, y를... ',
#   'link': 'https://blog.naver.com/13_11_16a/224084302144',
#   'postdate': '20251123',
#   'title': '<b>파이썬</b>으로 시작프로그램을 관리하는 exe 만들기'},
#  {'bloggerlink': 'blog.naver.com/officialgnu',
#   'bloggername': '경상국립대학교 공식 블로그',
#   'description': '위한 ‘<b>파이썬</b>을 활용한 재직자 역량강화 교육’을 실시했습니다. 이번 교육은 대기업과 지역... '
#                  '교육 과정은 실무 중심의 <b>파이썬</b> 데이터 처리 기초를 다뤘습니다. 주요 내용은 ▲항공 데이터 구조 '
#                  '이해... ',
#   'link': 'https://blog.naver.com/officialgnu/224122976528',
#   'postdate': '20251226',
#   'title': '항공우주 재직자 대상 ‘<b>파이썬</b> 활용 역량강화 교육’ 진행'},
#  {'bloggerlink': 'blog.naver.com/hactoefl',
#   'bloggername': '해커스 유학 블로그',
#   'description': '요즘 취업 준비나 이직을 준비하면서 &quot;<b>파이썬</b> 기초&quot;에 대해 다들 관심이 '
#                  '많으신데요! IT 직무뿐만 아니라 마케팅/데이터분석/기획/사무직까지 활용도가 워낙 높다 보니 요즘은 '
#                  '<b>파이썬</b> 비전공자분들도 코딩... ',
#   'link': 'https://blog.naver.com/hactoefl/224119900811',
#   'postdate': '20251224',
#   'title': '<b>파이썬</b> 기초, 비전공자도 공부 가능한 실무 코딩 인강 추천'},
#  {'bloggerlink': 'blog.naver.com/kidsn_future',
#   'bloggername': '아이들과미래재단 공식블로그',
#   'description': "[4기 모집] HD현대와 아이들과미래재단이 함께하는 미래 인재 육성 프로젝트, 'HD현대 <b>파이썬</b> "
#                  "교육' 참가자 모집 미래 사회의 필수 역량, HD현대 <b>파이썬</b> 교육 4차 산업혁명 시대가 도래함에 "
#                  '따라 디지털 및... ',
#   'link': 'https://blog.naver.com/kidsn_future/224078418234',
#   'postdate': '20251117',
#   'title': '[HD현대] <b>파이썬</b> 교육 4기 (CSM) 참여자 모집 안내 (~12/11까지)'},
#  {'bloggerlink': 'blog.naver.com/sbculture1',
#   'bloggername': '성북문화재단',
#   'description': '올 겨울 진짜 어른들이 쓰는 코딩 언어인 <b>파이썬</b>을 처음 경험해보는 시간을 준비했습니다. '
#                  '학년이... 서울여대 정보보안학과 대학생과 함께하는 겨울방학 ICT특화 프로그램 &quot;처음 만나는 '
#                  '<b>파이썬</b>&quot; 일시... ',
#   'link': 'https://blog.naver.com/sbculture1/224161276312',
#   'postdate': '20260127',
#   'title': '[글빛도서관] 처음 만나는 <b>파이썬</b>'},
#  {'bloggerlink': 'blog.naver.com/voodoo7',
#   'bloggername': '티파의 게임 라이프',
#   'description': '애로우헤드 게임 스튜디오가 헬다이버즈 2의 다음 프리미엄 전쟁채권인 <b>파이썬</b> 코만도스가 12월 '
#                  '3일... 헬다이버즈 2 <b>파이썬</b> 코만도스 전쟁채권 공개 플레이스테이션 블로그 최신 게시물에서 '
#                  '애로우헤드... ',
#   'link': 'https://blog.naver.com/voodoo7/224088366219',
#   'postdate': '20251126',
#   'title': '헬다이버즈 2 <b>파이썬</b> 코만도스 전쟁채권 공개'},
#  {'bloggerlink': 'blog.naver.com/ocublog',
#   'bloggername': '일과 학업을 동시에! 한국열린사이버대학교!',
#   'description': '<b>파이썬</b> 자격은 <b>파이썬</b> 프로그래밍 능력을 평가하는 민간 자격증을 의미하는 것으로 '
#                  '다양한 분야에 활용되는 만큼 <b>파이썬</b> 자격 안내를 통해 준비하는 분들이 많으실 텐데요. '
#                  '<b>파이썬</b> 자격을 갖게 된다면 웹... ',
#   'link': 'https://blog.naver.com/ocublog/224088542946',
#   'postdate': '20251126',
#   'title': '<b>파이썬</b> 자격 안내 나노·마이크로디그리 과정으로 든든히... '},
#  {'bloggerlink': 'blog.naver.com/nabilera1',
#   'bloggername': '김동균의 소프트웨어아카데미(2004~ )',
#   'description': '#<b>파이썬</b>기초 #교사연수자료 #학습자료 #캐글 #타이타닉 지난 주 데이터분석 주제로 만들어본 '
#                  '교사... 다운로드 받으세요.(html파일) 첨부파일 python_pandas_quiz_20.html '
#                  '머신러닝을 배우기 전, 왜 <b>파이썬</b>과 판다스를... ',
#   'link': 'https://blog.naver.com/nabilera1/224084561478',
#   'postdate': '20251122',
#   'title': '데이터분석 교사 연수용 (<b>파이썬</b> 판다스 퀴즈 문제)'},
#  {'bloggerlink': 'blog.naver.com/itbankkr',
#   'bloggername': 'IT국비지원 – 왕초보에서 취업까지',
#   'description': "사이에서 '강남<b>파이썬</b> 국비지원 과정'이 꾸준히 검색되는 이유는 분명합니다. ✔ 비전공자도 시작 "
#                  '가능 ✔ 교육비 부담 최소화 ✔ 취업 연계까지 가능 특히 <b>파이썬</b>은 데이터 분석, 자동화, AI, '
#                  '웹 개발 등 활용... ',
#   'link': 'https://blog.naver.com/itbankkr/224140330688',
#   'postdate': '20260109',
#   'title': '강남<b>파이썬</b> 국비지원 학원 추천 l 비전공자도 가능한 이유'},
#  {'bloggerlink': 'blog.naver.com/kacnet',
#   'bloggername': '고려아카데미컨설팅',
#   'description': '<b>파이썬</b>, 왜 지금 시작해야 할까요? 요즘 주변에서 <b>파이썬</b> 이야기 정말 많이 '
#                  '들으시죠? 예전에는 엑셀 잘하는 사람이 기본이었지만, 이제는 <b>파이썬</b>을 잘 다루는 사람이 곧 '
#                  '경쟁력이 되는 시대가 되었어요.... ',
#   'link': 'https://blog.naver.com/kacnet/224083222675',
#   'postdate': '20251121',
#   'title': '<b>파이썬</b>, 왜 지금 배워야 할까?AI 시대 필수 스킬 <b>파이썬</b>!'},
#  {'bloggerlink': 'blog.naver.com/jhc3044',
#   'bloggername': '처리씨 ⓙ ⓗ ⓒ 3 0 4 4',
#   'description': '[리뷰] <b>파이썬</b> 입문, 이론은 짧게! 실전은 알차게! &lt;만들면서 배우는 <b>파이썬</b> '
#                  '프로젝트&gt; 요즘 코딩 공부, 특히 <b>파이썬</b>에 관심 있는 분들 정말 많으시죠? 저도 야심 차게 '
#                  '시작했다가 지루한 문법 설명에 금방 지치곤... ',
#   'link': 'https://blog.naver.com/jhc3044/224166458523',
#   'postdate': '20260131',
#   'title': '[리뷰] <b>파이썬</b> 입문, 이론은... &lt;만들면서 배우는 <b>파이썬</b>... '},
#  {'bloggerlink': 'blog.naver.com/travelencyclopedia',
#   'bloggername': '여행백과사진',
#   'description': 'write(&quot;<b>파이썬</b> 파일 쓰기&quot;) 읽기 with '
#                  'open(&quot;test.txt&quot;, &quot;r&quot;) as file: '
#                  'print(file.read())  close() 자동 처리... 뼈대 <b>파이썬</b>이랑 SQL 차이 '
#                  '구분 <b>파이썬</b> SQL 역할 계산·로직 데이터 관리 대상 변수... ',
#   'link': 'https://blog.naver.com/travelencyclopedia/224170440574',
#   'postdate': '20260203',
#   'title': '<b>파이썬</b> 강의 #9'},
#  {'bloggerlink': 'blog.naver.com/comncom_edu',
#   'bloggername': '한국정보인재개발원-빅데이터,파이썬,R활용,6시그마',
#   'description': '이번에 국민대학교에서 재학생 대상 대면으로 <b>파이썬</b> 프로그래밍 활용 실무 과정 교육을 '
#                  '진행했는데요! 지금부터 대면 교육후기를 보여드릴게요!!^^ <b>파이썬</b>이란? <b>파이썬</b>은 '
#                  '최근에 상당히 크게 관심받고 있는... ',
#   'link': 'https://blog.naver.com/comncom_edu/224172610387',
#   'postdate': '20260205',
#   'title': '프로그램- <b>파이썬</b>프로그래밍활용능력 2급 교육 후기 (2026.01.... '},
#  {'bloggerlink': 'blog.naver.com/techshare',
#   'bloggername': 'techshare',
#   'description': '<b>파이썬</b> 언어에서 굳이 이와 비슷한 방법을 찾자면 import hook이 있는데요, # PEP '
#                  '302... 보이지만, <b>파이썬</b> 언어의 &quot;import&quot;가 가진 특성을 감안하면 '
#                  '사실상 &quot;모듈이 로드되고... ',
#   'link': 'https://blog.naver.com/techshare/224171885182',
#   'postdate': '20260204',
#   'title': '<b>파이썬</b> - 모듈의 로드 시점만 감지하는 방법'},
#  {'bloggerlink': 'blog.naver.com/travelencyclopedia',
#   'bloggername': '여행백과사진',
#   'description': '[1, &quot;<b>파이썬</b>&quot;, 3.5] (하지만 보통은 같은 종류만 넣음) 리스트 기본 '
#                  '사용법 값 꺼내기... 필수 <b>파이썬</b>에서 가장 많이 쓰는 자료구조 다음으로 이어가면 딱 좋아:  '
#                  '리스트 인덱싱... ',
#   'link': 'https://blog.naver.com/travelencyclopedia/224169097851',
#   'postdate': '20260202',
#   'title': '<b>파이썬</b> 강의 #8'},
#  {'bloggerlink': 'blog.naver.com/samyangmedia',
#   'bloggername': '삼양미디어 공식 블로그',
#   'description': '★ 사용한 프로그래밍 언어 ★ <b>파이썬</b>(Python) &lt;주요 특장점&gt; - 2022개정 '
#                  '교육과정을 분석하여 충실히 반영한 교과서로, <b>파이썬</b>(Python) 기반으로 구성했습니다. - '
#                  '프로그래밍 언어 기초를 효과적으로... ',
#   'link': 'https://blog.naver.com/samyangmedia/224080227858',
#   'postdate': '20251118',
#   'title': '2022개정 프로그래밍(<b>파이썬</b>)'},
#  {'bloggerlink': 'blog.naver.com/smartienz',
#   'bloggername': '디지털 글쟁이의 스마티엔즈',
#   'description': '<b>파이썬</b> 가상환경이란 무엇인가? <b>파이썬</b> 가상환경(Virtual Environment) '
#                  '이란, 프로젝트마다 독립적인 <b>파이썬</b> 실행 환경을 만들어 주는 기능을 말한다. 하나의 PC에 여러 '
#                  '프로젝트가 존재하더라도, 각... ',
#   'link': 'https://blog.naver.com/smartienz/224109744001',
#   'postdate': '20251214',
#   'title': '<b>파이썬</b> 가상환경 생성(활성화) 핵심 정리'},
#  {'bloggerlink': 'blog.naver.com/hj1124',
#   'bloggername': '나의 바다, 그곳은',
#   'description': '<b>파이썬</b> 코드는 별도의 폴더를 만들고, 그 안에 별도의 .py 파일로 나눠서 관리하기 쉽게... '
#                  '<b>파이썬</b> 코드는 PEP 8 스타일 가이드를 따르고, Black으로 자동 포맷, Flake8으로 '
#                  '린팅한다.... ',
#   'link': 'https://blog.naver.com/hj1124/224145900593',
#   'postdate': '20260114',
#   'title': '<b>파이썬</b> 코드를 짤때 필요한 것들'},
#  {'bloggerlink': 'blog.naver.com/funnycry',
#   'bloggername': '새벽소리의 서랍장',
#   'description': '<b>파이썬</b>책 온라인코딩학습을 함께 할 수 있는 &lt;똑똑한 <b>파이썬</b>&gt; 아이들은 '
#                  '스마트 학습기기 내에 있는 코딩 학습, 도서관 프로그램, 학교 방과 후 컴퓨터 수업 등 아주 자연스럽게 '
#                  '코딩과 친해지고 있다. 애들은... ',
#   'link': 'https://blog.naver.com/funnycry/224119152964',
#   'postdate': '20251222',
#   'title': '<b>파이썬</b>책 온라인코딩학습을 함께 할 수 있는 &lt;똑똑한 <b>파이썬</b>&gt;'},
#  {'bloggerlink': 'blog.naver.com/jamduino',
#   'bloggername': '실적을 만드는 코딩학원 잼코딩학원',
#   'description': '<b>파이썬</b> 챗북 활용 중 일부 챗북과 함께라면 질문을 망설이다 하지 못하고 넘어가는 일이 '
#                  '사라집니다.... 챗북을 활용한 이번 특강은 소중한 겨울방학기간동안 <b>파이썬</b>을 배울 수 있는 가장 '
#                  '효율적인 방법이라... ',
#   'link': 'https://blog.naver.com/jamduino/224139436991',
#   'postdate': '20260108',
#   'title': '잼코딩 대치본원 / 온라인관 - <b>파이썬</b> 기초제어문 6회 특강 (50... '},
#  {'bloggerlink': 'blog.naver.com/nabilera1',
#   'bloggername': '김동균의 소프트웨어아카데미(2004~ )',
#   'description': '#<b>파이썬</b>기초 #<b>파이썬</b>퀴즈 #수업자료 #학습자료 #대구온라인학교수업자료  '
#                  '<b>파이썬</b> 기초 실력 점검 (25문항) 2026 대구온라인학교 공동교육과정 정보과학 1일차 학습자 '
#                  '수준... ',
#   'link': 'https://blog.naver.com/nabilera1/224133140922',
#   'postdate': '20260103',
#   'title': '(Python 퀴즈) <b>파이썬</b> 기초 실력 점검 (25문항)'},
#  {'bloggerlink': 'blog.naver.com/gitacademy01',
#   'bloggername': '그린컴퓨터아트학원 공식블로그',
#   'description': '오늘은 AI 활용 능력과 실무 중심 개발 역량을 갖추면서, 웹·IT 개발 분야 취업까지 가능한 대전 '
#                  '그린컴퓨터아트학원의 AI<b>파이썬</b> 강의를 소개해 드리려고 합니다! [디지털컨버젼스] AI활용 '
#                  '<b>파이썬</b>(Python)... ',
#   'link': 'https://blog.naver.com/gitacademy01/224143883840',
#   'postdate': '20260112',
#   'title': '대전AI<b>파이썬</b>학원 웹개발자로 취업하는 법'},
#  {'bloggerlink': 'blog.naver.com/travelencyclopedia',
#   'bloggername': '여행백과사진',
#   'description': 'b = &quot;<b>파이썬</b>&quot; print(a + b) 결과  안녕<b>파이썬</b>  숫자 '
#                  '더하기랑 다르게 이어 붙인다 2️⃣ 문자열 곱하기 * (반복) text = &quot;하이 &quot; '
#                  'print(text * 3) 결과  하이 하이 하이 3️⃣ 문자열 + 숫자... ',
#   'link': 'https://blog.naver.com/travelencyclopedia/224153664539',
#   'postdate': '20260120',
#   'title': '<b>파이썬</b> 강의 #3'},
#  {'bloggerlink': 'blog.naver.com/jeipubmarketer',
#   'bloggername': '제이펍',
#   'description': '《LUVIT♥ <b>파이썬</b>으로 만드는 초경량 한국어 LLM 챗봇》은 <b>파이썬</b> 기초부터 '
#                  '데이터 분석, 머신러닝/딥러닝, 그리고 한국어 LLM 챗봇 구현까지- 하나의 흐름으로 따라가며 배우는 실습 '
#                  '중심 입문서입니다.... ',
#   'link': 'https://blog.naver.com/jeipubmarketer/224137940795',
#   'postdate': '20260107',
#   'title': '신간소개 | LUVIT♥ <b>파이썬</b>으로 만드는 초경량 한국어 LLM 챗봇'},
#  {'bloggerlink': 'blog.naver.com/saintbell',
#   'bloggername': 'Sam의 필리핀 Life ~',
#   'description': '개인 서버에서 운영하는 자동화 <b>파이썬</b> 코드가 있음 몇달동안 한번도 에러가 발생하지 '
#                  '않았는데..... ✅ 해결 방법 가장 확실하고 간단한 해결책은 <b>파이썬</b> 스크립트 또는 IDE(예: '
#                  'PyCharm, VS Code)를 관리자... ',
#   'link': 'https://blog.naver.com/saintbell/224097152916',
#   'postdate': '20251203',
#   'title': '<b>파이썬</b> [WinError 5] 액세스가 거부되었습니다'},
#  {'bloggerlink': 'blog.naver.com/doremefa9',
#   'bloggername': '꿈잘러의 레퍼런스',
#   'description': '작년 연말 즈음 <b>파이썬</b> 공부를 시작하겠다고 올 초 부터 호기롭게 학원을 끊어서 아주 기본 '
#                  '연산정도를... ㅋㅋㅋㅋ (봐도봐도 모르겠는 인강 허허허) #사십대 #일상 #일기 #워킹맘 '
#                  '#<b>파이썬</b> #공부시작 #40대<b>파이썬</b>... ',
#   'link': 'https://blog.naver.com/doremefa9/224122654701',
#   'postdate': '20251225',
#   'title': '<b>파이썬</b> 공부를 다시 시작했어요.'},
#  {'bloggerlink': 'blog.naver.com/travelencyclopedia',
#   'bloggername': '여행백과사진',
#   'description': '좋아  **<b>파이썬</b> 정규 표현식(Regex)**을 어렵게 말 안 하고, “왜 쓰는지 → 어떻게 '
#                  '쓰는지... 2️⃣ <b>파이썬</b>에서 쓰려면 먼저 이것부터 import re re = regex 모듈 '
#                  '3️⃣ 가장 기본적인 사용... ',
#   'link': 'https://blog.naver.com/travelencyclopedia/224171852385',
#   'postdate': '20260204',
#   'title': '<b>파이썬</b> 강의 #11'},
#  {'bloggerlink': 'blog.naver.com/travelencyclopedia',
#   'bloggername': '여행백과사진',
#   'description': "b = '<b>파이썬</b>' 큰따옴표 &quot; 작은따옴표 '  둘 다 가능 2️⃣ 문자열 + 문자열 "
#                  '(붙이기) a = &quot;안녕&quot; b = &quot;<b>파이썬</b>&quot; print(a '
#                  '+ b) 출력: 안녕<b>파이썬</b> 3️⃣ 문자열 × 숫자 (반복) print(&quot;하이 '
#                  '&quot; * 3)... ',
#   'link': 'https://blog.naver.com/travelencyclopedia/224156330167',
#   'postdate': '20260122',
#   'title': '<b>파이썬</b> 강의 #7'},
#  {'bloggerlink': 'blog.naver.com/handamen',
#   'bloggername': '한국사회컴퓨터학원',
#   'description': '그래도 많이 좋아져서 지난 일요일부터 프로그래밍기능사필기 <b>파이썬</b> 보강자료(교재)를 제작하고 '
#                  '있습니다. 기존에 작업했던 <b>파이썬</b> 학원교재를 베이스로 작업이 완료되고 있었는데요. 오늘 '
#                  '2026년 1회... ',
#   'link': 'https://blog.naver.com/handamen/224171823452',
#   'postdate': '20260204',
#   'title': '[이기적] <b>파이썬</b> 보강자료 마무리중입니다.'},
#  {'bloggerlink': 'blog.naver.com/nabilera1',
#   'bloggername': '김동균의 소프트웨어아카데미(2004~ )',
#   'description': '#<b>파이썬</b>기초 #수업자료 #학습자료 #중학교정보 #순서도 #흐름도 #의사코드 아들이 중학교 1학년 '
#                  '주말... “신라면 끓이기” 의사코드, 순서도, <b>파이썬</b> 코드 1. 의사코드 '
#                  '(Pseudocode) 자연어와 알고리즘적... ',
#   'link': 'https://blog.naver.com/nabilera1/224007225526',
#   'postdate': '20250914',
#   'title': '중학교, “신라면 끓이기”  의사코드, 순서도, <b>파이썬</b> 코드'},
#  {'bloggerlink': 'blog.naver.com/techshare',
#   'bloggername': 'techshare',
#   'description': '첫 번째 로드되는 <b>파이썬</b> 모듈은, # app.py import sys current_module '
#                  '= sys.modules[__name... 이 외에 embeddable package로 배포된 '
#                  '<b>파이썬</b>의 경우, <b>파이썬</b> 관련 기본 모듈들이 zip... ',
#   'link': 'https://blog.naver.com/techshare/224167352130',
#   'postdate': '20260201',
#   'title': '<b>파이썬</b> - sitecustomize.py의 &quot;__main__&quot; 모듈'},
#  {'bloggerlink': 'blog.naver.com/techshare',
#   'bloggername': 'techshare',
#   'description': 'py 파일을 다시 한번 실습해 볼 기회가 생겼는데, 모든 <b>파이썬</b> 프로세스에... 있어서, '
#                  '<b>파이썬</b> - &quot;Windows embeddable package&quot;로 개발 환경 '
#                  '구성하는 방법 ; https://www.sysnet.... ',
#   'link': 'https://blog.naver.com/techshare/224167351405',
#   'postdate': '20260201',
#   'title': '<b>파이썬</b> - sitecustomize.py가 실행되지 않는 경우(_pth 파일)'},
#  {'bloggerlink': 'blog.naver.com/jamsuham75',
#   'bloggername': '이창현 코딩연구소',
#   'description': '이번 과정에서 『나 혼자 <b>파이썬</b>』 저자 직강으로 <b>파이썬</b> 강의를 진행합니다. 이 '
#                  '강의는 단순한 문법 나열이 아니라,  책을 집필한 저자가 직접 설명하는 흐름 중심 수업입니다. 왜 이 문법이 '
#                  '필요한지... ',
#   'link': 'https://blog.naver.com/jamsuham75/224165136984',
#   'postdate': '20260130',
#   'title': '「나 혼자 <b>파이썬</b>」 저자 직강'},
#  {'bloggerlink': 'blog.naver.com/roseka',
#   'bloggername': '가요이 경제노트',
#   'description': '<b>파이썬</b> 기본 문법 변수 조건문 (if, elif, else) 반복문 (for, while) 함수 '
#                  '(def) <b>파이썬</b> 리스트 리스트 list 튜플 tuple 딕셔너리 dictionary 세트 '
#                  'set 변수 변수 : 데이터 저장 공간... ',
#   'link': 'https://blog.naver.com/roseka/224142945284',
#   'postdate': '20260111',
#   'title': '<b>파이썬</b> 기본 문법, 리스트, 튜플, 딕셔너리, 세트'},
#  {'bloggerlink': 'blog.naver.com/hj1124',
#   'bloggername': '나의 바다, 그곳은',
#   'description': '<b>파이썬</b> edge-tts를 사용하여 텍스트를 음성으로 변경하고 mp4로 다운받는 것 '
#                  '<b>파이썬</b>코드 &quot;&quot;&quot; 한글 TTS Blueprint - edge-tts '
#                  '전용 edge-tts로 MP3 생성, moviepy로... ',
#   'link': 'https://blog.naver.com/hj1124/224168298816',
#   'postdate': '20260202',
#   'title': '<b>파이썬</b> TTS프로그램 코드'},
#  {'bloggerlink': 'blog.naver.com/ysth_news',
#   'bloggername': '서인고 꿈이루미',
#   'description': '바로 YBM IT CosPro <b>파이썬</b> 자격시험에 총 18명이 합격한 소식인데요!  특히 바쁘신 '
#                  '학기말에도 기꺼이... #서울인공지능고 #직업교육혁신지구 #CosPro #YBM자격증 #<b>파이썬</b> '
#                  '#프로그래밍자격증 #AI교육... ',
#   'link': 'https://blog.naver.com/ysth_news/224173806937',
#   'postdate': '20260206',
#   'title': '[직업교육혁신지구사업] YBM IT CosPro <b>파이썬</b> 자격증 18명... '},
#  {'bloggerlink': 'blog.naver.com/gyugyugyugyugyu',
#   'bloggername': 'Nobody Else',
#   'description': '중에서 <b>파이썬</b>기반 빅데이터분석마케팅전문가 고려해본 적 있으신가요? 디지털 전환이 더욱 '
#                  '가속화되면서 마케팅 분야에서도 데이터 분석 역량은 선택이 아닌 필수가 된 세상입니다. 특히나 '
#                  '<b>파이썬</b>을... ',
#   'link': 'https://blog.naver.com/gyugyugyugyugyu/224173838562',
#   'postdate': '20260206',
#   'title': '<b>파이썬</b>기반 빅데이터분석마케팅전문가 관심이 있으시다면... '}]

# %%
#data/blog.json 파일 생성기
import json

with open('data/blog.json','w',encoding='utf-8') as file:
    json.dump(items_data, file)
